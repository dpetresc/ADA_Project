# %% [markdown]
# ## Creation of the dataset

# %% [markdown]
# We have two datasets
#  - Amazon Customer Review dataset :
#    - amazon_reviews_us_Books_v1_00.tsv.gz (2.74 Go)
#    - amazon_reviews_us_Books_v1_01.tsv.gz (2.69 Go)
#    - amazon_reviews_us_Books_v1_02.tsv.gz (1.33 Go)
#  - Amazon Book Cover dataset :
#    - book32-listing.csv (39.5 Mo)
#
# Each row of the first dataset represents a review. Therefore we could have several rows representing the same book (several reviews for the same book).
#
# Each row of the second dataset represents a book.
#
# In this notebook, we merge the two datasets, in order to have each row of the new dataset representing a review, along with the cover of the corresponding book.
#
# Since the first dataset is pretty big, and to avoid creating a huge dataset, we will use the following pipeline :
#  - Load the cover file
#  - Load the first review file
#  - Merge the first review file in df_merge_1
#  - Load the second review file
#  - Merge the second review file in df_merge_2
#  - Load the third review file
#  - Merge the third review file in df_merge_3
#  - Merge df_merge_1, df_merge_2, and df_merge_3 in df_merge
#  - Save df_merge in merge.csv

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# First we load the cover image dataset

# %%
columns = ['product_id', 
           'filename', 
           'image_url', 
           'title', 
           'author', 
           'category_id', 
           'category']
df_covers = pd.read_csv("Data/book32-listing.csv", 
                        encoding = "ISO-8859-1", 
                        header=None, 
                        names=columns)
df_covers.head()
# Out:
#    product_id        filename  \
# 0   761183272  0761183272.jpg
# 1  1623439671  1623439671.jpg
# 2  B00O80WC6I  B00O80WC6I.jpg
# 3   761182187  0761182187.jpg
# 4  1578052084  1578052084.jpg
#
#                                            image_url  \
# 0  http://ecx.images-amazon.com/images/I/61Y5cOdH...
# 1  http://ecx.images-amazon.com/images/I/61t-hrSw...
# 2  http://ecx.images-amazon.com/images/I/41X-KQqs...
# 3  http://ecx.images-amazon.com/images/I/61j-4gxJ...
# 4  http://ecx.images-amazon.com/images/I/51Ry4Tsq...
#
#                                                title              author  \
# 0                    Mom's Family Wall Calendar 2016      Sandra Boynton
# 1                    Doug the Pug 2016 Wall Calendar        Doug the Pug
# 2  Moleskine 2016 Weekly Notebook, 12M, Large, Bl...           Moleskine
# 3            365 Cats Color Page-A-Day Calendar 2016  Workman Publishing
# 4               Sierra Club Engagement Calendar 2016         Sierra Club
#
#    category_id   category
# 0            3  Calendars
# 1            3  Calendars
# 2            3  Calendars
# 3            3  Calendars
# 4            3  Calendars

# %% [markdown]
# We read the dataset containing the reviews. We have to specify the columns names because some rows have a higher count of cell than others. We want to see what is contained in these rows.

# %%
cols = ["marketplace",
        "customer_id",
        "review_id",
        "product_id",
        "product_parent",
        "product_title",
        "product_category",
        "star_rating",
        "helpful_votes",
        "total_votes",
        "vine",
        "verified_purchase",
        "review_headline",
        "review_body",
        "review_date", 
        "undefined_1",
        "undefined_2",
        "undefined_3",
        "undefined_4",
        "undefined_5",
        "undefined_6",
        "undefined_7"
       ]

# %%
df_reviews = pd.read_csv("Data/amazon_reviews_us_Books_v1_00.tsv.gz", 
                         names=cols, 
                         sep='\t', 
                         skiprows=1)
# Out:
# /anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7,17,18,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# The warning simply indicates that some columns do not have the same dtype for each row, this will be handled later by cleaning the data.
#
# So first we check the rows with a higher count of cells.

# %%
df_reviews[df_reviews["undefined_1"].notnull()]
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 3522             US     45223684  R1NHKVD5LMP2JY  1503551814       353548609
# 5280             US     18701079  R1946J1OJKC1K2  0743292472         7685359
# 20476            US     40945620  R33MH6R1TZWIGR  1452572747       523136939
# 25893            US     22921197  R1OPQAX1D7DWB8  0984755101       632337521
# 27014            US     44087253  R24H2K78E883A0  1616496169       709191612
# 59796            US     44250036   RYNEKW5P1Z3AG  0385262078       887509044
# 69196            US     50641462  R2VI5KEAQR2P23  0545436826       247155770
# 71951            US     43676679  R2F0SUDYHR79JQ  1844094642       766424526
# 78718            US      4881222  R21NUSCF1WC1I8  1607512572       236705009
# 81298            US      1148395  R1UH3R71GX97AR  1502716984       563128335
# 87681            US     50861690  R2Z0YTRQKVFHSF  0807403083       147336042
# 90514            US     28736875   RVFNQHOLE58A0  0806120940       661253970
# 91145            US     15629461    R4U6722KCUT6  1592408419       543673826
# 108943           US      8612032  R2V2ES66TGP7RN  1460268601       273651829
# 118287           US     50953132  R2YWTZB0TCB920  1439132852       537451993
# 124665           US     38871814  R1CQPRDZKZZKKN  097860783X       764135422
# 125539           US     26965291  R33FTU1VADZM18  1591843820       618286357
# 144113           US     19357930  R370TRRWYXD4HH  0743230418       757722318
# 167694           US     49384329  R2ZVVLUZWJ1EWP  1502328585       460342874
# 179854           US     51750629  R1919SOCLXFHH3  1456550144       598402352
# 189710           US     41990563   RBWE5V226JS4A  0762454865       402819053
# 196486           US     20804529  R1W0RQ0ETQT7V9  1475812140       387091568
# 232130           US     26084626   RX8T8JKA1RCM4  0062333933       223598514
# 241732           US     36457256  R32B42EMWA43S7  1400076560       204550997
# 269921           US     17688934   R70Y8Z54OL2OW  0316210463       723771425
# 279156           US     12975716  R3KDGN68ECWPFL  1285755618       475852195
# 283355           US     15648568  R22WHMC556RKAR  386521584X       467228901
# 285765           US     11380786  R12VP0F0Q16NMF  0971339309       192326528
# 308164           US     41713493  R1EW4GKVIF0ALE  1503019500       768980686
# 315197           US     45994291   RK3U2RRENGDFM  1511510056       439740394
# ...             ...          ...             ...         ...             ...
# 4449651          US      2484994  R3K2FPQZ7X8UVP  1497437016       519821647
# 4459300          US     40203782  R1SILLK0ZNLGSD  1434238822       755154206
# 4477211          US     14426796  R3HBOV96BGZSP2  0870717421       769808046
# 4500861          US     13558114  R2F60Z8M7MYER2  038573252X       305985379
# 4549884          US     46366696  R2PAOB044HM77A  1492927449       113630502
# 4552286          US      4274094   RXS1XC8LMKG1Y  0823422437       304889763
# 4558857          US     27197209  R2GNMOUPSY80XK  1611861314       616413203
# 4562249          US     49569659   R7N4GP96VKLSA  9231039911       306686978
# 4567912          US     52956445  R13129ZA040001  0470376295       280360616
# 4633359          US     37024654   RGSFJRNLHB30C  0199654441       755550981
# 4640815          US     19973002  R2OQPGHTYWVCZ2  0991067886       313246709
# 4644915          US     30817773  R1WAHI6773B6KO  1497511135       946709255
# 4671851          US     32651993  R3UV6QM6ZDKGYU  0385184581       212671778
# 4701152          US      6071575   R9V19CKJTF8GG  055380653X       483985572
# 4721068          US     38970700   RRGRPELJQGFI6  0822210738       994387679
# 4731354          US     36857681  R3S1ZPUV914YNM  0761536434       630858517
# 4744853          US     44416620  R1ZCFR2H9H98QN  1402720602        84227631
# 4939718          US     47464628  R1RTM2W1I88ZGU  031074265X       972127661
# 5184881          US     16100572  R10J8LHGN2V8TO  1935166301       218847016
# 5279518          US     23841074  R1IVV5GIR97AWN  0826198775       800958859
# 5303008          US      5514026  R3GDXEME5MDQ1Z  B000J17S1O       538483493
# 5659630          US     17134921  R1EPGM64YQYUAZ  1595828273       822992594
# 5893490          US     19412473  R3LOK2DEVL2M4E  1623430011       360632523
# 5906171          US     33983982   RV0IRPSEY6RRB  0980006619       249502078
# 6053732          US     43998573  R227N5S9GYXA5F  1601631898       305019394
# 6250798          US     41469705   RHXMNBCSITSC2  1416955070       214775024
# 6525508          US      8821750  R1DWL8R14NFHZR  1591963419        73629897
# 6704023          US     51304162   RXIZDJNXIOA1I  0897451902       810996727
# 7724706          US     16044781  R2YDMT5YFQLR9U  1883319617       458509709
# 8647347          US      9715059   RUDU7GWRQ6JLR  1475283113       473174984
#
#                                              product_title product_category  \
# 3522         A Nutty World: On the Edge of the Rain Forest            Books
# 5280     The Ultimate Battle: Okinawa 1945--The Last Ep...            Books
# 20476    Have This Mind: Supreme Happiness, Ultimate Re...            Books
# 25893    The Primal Connection: Follow Your Genetic Blu...            Books
# 27014    Navigating Grace: A Solo Voyage of Survival an...            Books
# 59796                          The Impossible H L. Mencken            Books
# 69196                                          Friendshape            Books
# 71951    Change Your Story, Change Your Life: Using Sha...            Books
# 78718                            The House on Tradd Street            Books
# 81298    Jack The Ripper: Newly Discovered Adventures o...            Books
# 87681    1: Torah Commentary for Our Times: Genesis (To...            Books
# 90514    The Pawnee Indians (The Civilization of the Am...            Books
# 91145    Daring Greatly: How the Courage to Be Vulnerab...            Books
# 108943              The New Arcadia - Tahiti's Cursed Myth            Books
# 118287                      International (Monster Hunter)            Books
# 124665                              Five Minutes With VITO            Books
# 125539    Idea Man: A Memoir by the Cofounder of Microsoft            Books
# 144113                                           Tarantula            Books
# 167694    The Art of Kumomi: Finding Meaning in Randomness            Books
# 179854                                          The Nimrod            Books
# 189710   Rose Water and Orange Blossoms: Fresh & Classi...            Books
# 196486   Massaging the Mindset: An Intelligent Approach...            Books
# 232130          Heretic: Why Islam Needs a Reformation Now            Books
# 241732                 The In-Between World of Vikram Lall            Books
# 269921                               Courage for Beginners            Books
# 279156   Abnormal Psychology: An Integrative Approach, ...            Books
# 283355                                       The Americans            Books
# 285765                         What Works When Diets Don't            Books
# 308164                                Love Overcomes Grief            Books
# 315197                       wings and things: art therapy            Books
# ...                                                    ...              ...
# 4449651  Formierung der Struktur des eigenen Denkens (G...            Books
# 4459300  How the Rhinoceros Got His Skin: The Graphic N...            Books
# 4477211  Trying Home: The Rise and Fall of an Anarchist...            Books
# 4500861  Inside Delta Force: The Story of America's Eli...            Books
# 4549884  Are the Keys in the Freezer?: An Advocate's Gu...            Books
# 4552286                                   A Dog on His Own            Books
# 4558857  Dangerous Friendship: Stanley Levison, Martin ...            Books
# 4562249  Eliminating Corporal Punishment: The Way Forwa...            Books
# 4567912  Generation on a Tightrope: A Portrait of Today...            Books
# 4633359                       Linear Algebra: Step by Step            Books
# 4640815                                Running for my Life            Books
# 4644915  Bully Beyond the Tower: A Collection of Peer R...            Books
# 4671851  Magnificence and misery: A firsthand account o...            Books
# 4701152       Toms River: A Story of Science and Salvation            Books
# 4721068                             The Star-Spangled Girl            Books
# 4731354  The Ultimate History of Video Games: From Pong...            Books
# 4744853  Classical Guitar Making: A Modern Approach to ...            Books
# 4939718  Life Behind the Wall: Candy Bombers, Beetle Bu...            Books
# 5184881  In Sheep's Clothing: Understanding and Dealing...            Books
# 5279518  Methods for Community Public Health Research: ...            Books
# 5303008  Negro Politicians: The RIse of Negro Politics ...            Books
# 5659630           Hellboy, Vol. 12: The Storm and The Fury            Books
# 5893490         B.C. Reinvents the Wheel 2014 Box Calendar            Books
# 5906171                                     Catechism Tabs            Books
# 6053732                                 The Big Book of HR            Books
# 6250798     City of Bones (The Mortal Instruments, Book 1)            Books
# 6525508                  Caballo Negro Cantos de la Muerte            Books
# 6704023                     Blue Catalinas of World War II            Books
# 7724706  Hollywood vs. The Aliens: The Motion Picture I...            Books
# 8647347                                    Parallel Dreams            Books
#
#         star_rating  helpful_votes  total_votes     ...      \
# 3522              5            0.0          0.0     ...
# 5280              5            0.0          0.0     ...
# 20476             5            1.0          1.0     ...
# 25893             5            0.0          0.0     ...
# 27014             5            2.0          2.0     ...
# 59796             5            0.0          0.0     ...
# 69196             3            6.0          6.0     ...
# 71951             2            4.0         16.0     ...
# 78718             4            0.0          0.0     ...
# 81298             1            1.0          2.0     ...
# 87681             5            0.0          0.0     ...
# 90514             2            0.0          2.0     ...
# 91145             2            3.0          4.0     ...
# 108943            4            0.0          1.0     ...
# 118287            2            3.0          9.0     ...
# 124665            2            0.0          0.0     ...
# 125539            5            0.0          0.0     ...
# 144113            1            2.0         11.0     ...
# 167694            5            1.0          1.0     ...
# 179854            5            0.0          0.0     ...
# 189710            5            0.0          0.0     ...
# 196486            5            0.0          0.0     ...
# 232130            5            2.0          2.0     ...
# 241732            4            0.0          0.0     ...
# 269921            4            0.0          1.0     ...
# 279156            1            2.0          9.0     ...
# 283355            5            5.0          6.0     ...
# 285765            4            2.0          2.0     ...
# 308164            5            1.0          1.0     ...
# 315197            5            4.0          4.0     ...
# ...             ...            ...          ...     ...
# 4449651           5            1.0          1.0     ...
# 4459300           5            0.0          0.0     ...
# 4477211           5            3.0          3.0     ...
# 4500861           5            0.0          0.0     ...
# 4549884           5            0.0          0.0     ...
# 4552286           5            0.0          0.0     ...
# 4558857           5            1.0          1.0     ...
# 4562249           5            0.0          0.0     ...
# 4567912           5            0.0          0.0     ...
# 4633359           5            3.0          3.0     ...
# 4640815           5            0.0          0.0     ...
# 4644915           5            0.0          0.0     ...
# 4671851           4            0.0          1.0     ...
# 4701152           5            1.0          1.0     ...
# 4721068           5            0.0          0.0     ...
# 4731354           5            0.0          0.0     ...
# 4744853           2            3.0          4.0     ...
# 4939718           5            0.0          0.0     ...
# 5184881           4            0.0          0.0     ...
# 5279518           5            0.0          0.0     ...
# 5303008           5            0.0          0.0     ...
# 5659630           5            0.0          1.0     ...
# 5893490           5            0.0          0.0     ...
# 5906171           5            0.0          0.0     ...
# 6053732           5            0.0          0.0     ...
# 6250798           2            0.0          0.0     ...
# 6525508           5            0.0          0.0     ...
# 6704023           5            0.0          0.0     ...
# 7724706           3            0.0          1.0     ...
# 8647347           5            0.0          0.0     ...
#
#                                            review_headline review_body  \
# 3522      She is a fine storyteller and has a message c...       Books
# 5280      was a great read. Quick-moving with sharp int...       Books
# 20476    This wonderful book is thoughtful and well-wri...       Books
# 25893     this is the best book on health and wellness ...       Books
# 27014    Oh would some Power the gift give us, To ...\t...       Books
# 59796     One of the most important of all American men...       Books
# 69196     It is a bunch of sweet musings about friendsh...       Books
# 71951     I intensely dislike the psychology perspectiv...       Books
# 78718    discriptive of characters w/repetitive plot di...       Books
# 81298     is a complete waste of time and money\tthis &...       Books
# 87681     his choice of examples is excellent, his comm...       Books
# 90514    The raiders carried off such great numbers of ...       Books
# 91145    If you want to be happy in life\tAll hyped up ...       Books
# 108943   The New Arcadia offers a vital and compelling ...       Books
# 118287   Guns good! Guvmint bad\tsorry two stars. I cou...       Books
# 124665    If you're looking for an introduction to the ...       Books
# 125539    This was a great book. Remember two things\tI...       Books
# 144113   I WARNED YOU!\tSTOOPIDIST, MOST IDIOTIC, NON-S...       Books
# 167694    I took Karen's class at Art Unraveled and I w...       Books
# 179854   damn fine work, sir\tSuperb! Sometimes you rea...       Books
# 189710    I can see why he recommended this book\tAntho...       Books
# 196486   Awesome book!... a refreshing take on ...\t&#3...       Books
# 232130    They all go a long way toward helping us unde...       Books
# 241732   The terror that permeated our world like a mys...       Books
# 269921   I really enjoyed this book\tFrom my daughter: ...       Books
# 279156   theirs was the only abnormal textbook reviewed...       Books
# 283355   Anybody doesn’t like these pitchers dont like ...       Books
# 285765   What Works When Diets Don't has become and rem...       Books
# 308164   For any child who has lost a close family memb...       Books
# 315197    I saw some of the pictures of her pages and f...       Books
# ...                                                    ...         ...
# 4449651  Zu wissen, die Quelle des Denkens, müssen die ...       Books
# 4459300   What matters though is the enjoyment, and bot...       Books
# 4477211   If you have an interest in the history of the...       Books
# 4500861   Awesome read. Service fast and furious\tBough...       Books
# 4549884   is a great book, there was so much research p...       Books
# 4552286  An awesome book! K-10 is great\t&#34;An awesom...       Books
# 4558857   reads like a mystery thriller\tMy Mother has ...       Books
# 4562249  That's sentimental crap! Those people just wan...       Books
# 4567912   It was a perfect profile of an entire generat...       Books
# 4633359   Excellent balance.\t&#34; Excellent balance.....       Books
# 4640815   I really enjoyed it.\tThis is a very inspirin...       Books
# 4644915  I enjoyed this book and learned ALOT about how...       Books
# 4671851  When gold fever set off the stampede for the K...       Books
# 4701152   Instead I realized once again that corporate ...       Books
# 4721068   Neil Simon is a brilliant writer. I love his ...       Books
# 4731354   but I'd love to see it\tI just finished this ...       Books
# 4744853   Does he seriously work like this? Bizarrely\t...       Books
# 4939718  Life Behind The Wall\tThe book for review is “...       Books
# 5184881  In Sheep's Clothing\tGood book guide for someo...       Books
# 5279518  Must-have” for all community researchers in pu...       Books
# 5303008  NEGRO POLITICIANS (OSCAR STANTON DE PRIEST)\tI...       Books
# 5659630  I won't be wronged, I won't be insulted, and I...       Books
# 5893490  Laughter does good, like a medicine.”   Prover...       Books
# 5906171  Catechism Tabs\tThe tabs provide easy and conv...       Books
# 6053732  Must have' guidebook for today's HR profession...       Books
# 6250798  Bored*\tHow is this popular literature??? How?...       Books
# 6525508  !!\tI need this book, I would love it if you g...       Books
# 6704023  Blue Catalinas of World War II\tI bought the b...       Books
# 7724706  tis a puzzlement...\tLike other reviewers I am...       Books
# 8647347  Poetic Dreams''\tShe is a true rhetorical tale...       Books
#
#         review_date undefined_1 undefined_2  undefined_3  undefined_4  \
# 3522              5         0.0         0.0            N            Y
# 5280              1         6.0         7.0            N            Y
# 20476             5         0.0         0.0            N            Y
# 25893             4         1.0         2.0            N            N
# 27014             5         0.0         0.0            N            Y
# 59796             5         0.0         0.0            N            Y
# 69196             5         0.0         0.0            N            N
# 71951             5         1.0         2.0            N            Y
# 78718             5         7.0         8.0            N            N
# 81298             5         0.0         0.0            N            Y
# 87681             5         1.0         2.0            N            Y
# 90514             5         2.0         2.0            N            Y
# 91145             4         0.0         0.0            N            Y
# 108943            3         0.0         0.0            N            N
# 118287            5         6.0         6.0            N            N
# 124665            5         0.0         0.0            N            Y
# 125539            5         0.0         1.0            N            Y
# 144113            5         0.0         0.0            N            Y
# 167694            5         3.0         3.0            N            Y
# 179854            5         1.0         1.0            N            Y
# 189710            5         0.0         0.0            N            N
# 196486            5         7.0         8.0            N            Y
# 232130            5         0.0         0.0            N            Y
# 241732            4         1.0         2.0            N            Y
# 269921            4         0.0         0.0            N            Y
# 279156            5         4.0         4.0            N            N
# 283355            5         0.0         0.0            N            Y
# 285765            5       114.0       129.0            N            N
# 308164            4         0.0         1.0            N            N
# 315197            3         0.0         0.0            N            Y
# ...             ...         ...         ...          ...          ...
# 4449651           5         0.0         0.0            N            Y
# 4459300           5         0.0         0.0            N            N
# 4477211           1         7.0         8.0            N            N
# 4500861           5         0.0         0.0            N            Y
# 4549884           5         0.0         0.0            N            Y
# 4552286           5         1.0         1.0            N            Y
# 4558857           5         3.0         3.0            N            Y
# 4562249           5         0.0         0.0            N            Y
# 4567912           2         0.0         0.0            N            Y
# 4633359           5         0.0         0.0            N            Y
# 4640815           2         0.0         2.0            N            Y
# 4644915           4         0.0         1.0            N            N
# 4671851           5         0.0         3.0            N            Y
# 4701152           5         0.0         0.0            N            Y
# 4721068           5         0.0         0.0            N            Y
# 4731354           5         0.0         0.0            N            Y
# 4744853           5         0.0         0.0            N            N
# 4939718           5         0.0         0.0            N            N
# 5184881           5         0.0         0.0            N            Y
# 5279518           1         2.0         2.0            N            N
# 5303008           4         2.0         5.0            N            Y
# 5659630           5         2.0         2.0            N            Y
# 5893490           5         3.0         3.0            N            N
# 5906171           5         0.0         0.0            N            Y
# 6053732           5         0.0         0.0            N            N
# 6250798           5         0.0         0.0            N            Y
# 6525508           3         0.0         3.0            N            Y
# 6704023           3         3.0         3.0            N            Y
# 7724706           5         1.0         1.0            N            Y
# 8647347           4         3.0         4.0            N            N
#
#                                                undefined_5  \
# 3522                                          looks great.
# 5280                   NOT PLEASED WITH THE VENDORS AT ALL
# 20476                                           Very good!
# 25893                                  Don't Be Mislead...
# 27014    It was a great experience and one I will alway...
# 59796    The storyline is great and the characters are ...
# 69196    ... have heard a few things about Medjugorje b...
# 71951                                           Five Stars
# 78718    I like Kevin Trudeau  - great information yet ...
# 81298                                           Five Stars
# 87681    THIS BOOK WAS AWESOME, WAS SAD WHEN I WAS DONE...
# 90514    This book can be a resource in multiple ways--...
# 91145         A well written fun book about a heavy topic.
# 108943   His writing style is as quirky as it is intell...
# 118287                                  My favorite book/s
# 124665        Very nice book. I gave as a gift and she ...
# 125539                                  Very entertaining!
# 144113         Good quality book arrived just as expected.
# 167694   Great book I am just a beginner pianist but th...
# 179854                                          Five Stars
# 189710          It is a great read and never a dull moment
# 196486      Ed is a fine soldier and just as good a writer
# 232130                                      Helpful guide.
# 241732                       Companion booklet, because???
# 269921                                          Four Stars
# 279156                                    If you like U. S
# 283355                      Great tips for differentiation
# 285765        Great Book to Help Your Child with Their ADD
# 308164   I love you, a thousand times over.  And I will...
# 315197        The plan works but it is so confusing, I ...
# ...                                                    ...
# 4449651                                            Awesome
# 4459300                                              Funny
# 4477211             I also was disappointed with this book
# 4500861                                         Five Stars
# 4549884                         Awesome author and seller.
# 4552286  I am very pleased that I took the plunge and o...
# 4558857                                  officially a fan!
# 4562249                                        Great Book.
# 4567912                                          Two Stars
# 4633359                                         Five Stars
# 4640815                                                 ):
# 4644915                                         Four Stars
# 4671851                                         Five Stars
# 4701152                                         Five Stars
# 4721068                                            perfect
# 4731354                   DOESN'T GET ANY BETTER THAN THIS
# 4744853                                           So great
# 4939718                                    Amazing Artist!
# 5184881                                this was a blessing
# 5279518                                       Nothing New!
# 5303008        Interesting analysis of controversial views
# 5659630                                         Eye Opener
# 5893490                                   Beautiful series
# 5906171                       EVERY MAN needs to read this
# 6053732                                        Interesting
# 6250798                                             Great!
# 6525508                                              It ok
# 6704023  Olney's Book is in TWQ Parts- Hopefully Seller...
# 7724706         Great cookbook for the not faint of heart!
# 8647347                               Vibrant, funny, wise
#
#                                                undefined_6 undefined_7
# 3522                           Very durable.  looks great.  2015-08-31
# 5280     THE CASE IS MADE OF A CHEAP QUALITY. IT BROKE ...  2015-08-31
# 20476                   Everything as promised. Very good!  2015-08-30
# 25893    This is not so much intended to be a review as...  2015-08-29
# 27014    After reading the book I visited Helen and too...  2015-08-29
# 59796    This book is the third in the series and in my...  2015-08-26
# 69196    I have heard a few things about Medjugorje but...  2015-08-25
# 71951                                              love it  2015-08-25
# 78718    I like Kevin Trudeau because he has made it hi...  2015-08-24
# 81298                   This item was received. Thank you.  2015-08-24
# 87681    THIS BOOK WAS AWESOME, WAS SAD WHEN I WAS DONE...  2015-08-23
# 90514    This book can be a resource in multiple ways--...  2015-08-23
# 91145    This was a book that I remember reading in one...  2015-08-23
# 108943   A fascinating idea and analysis of major histo...  2015-08-21
# 118287   Outstanding!! This is an incredible coloring b...  2015-08-20
# 124665   Very nice book.  I gave as a gift and she love...  2015-08-20
# 125539   Very entertaining, I really liked this book. I...  2015-08-20
# 144113   Good quality book arrived just as expected. It...  2015-08-18
# 167694   Great book I am just a beginner pianist but th...  2015-08-16
# 179854                                     Excellent book!  2015-08-15
# 189710   This book literally had me laughing the whole ...  2015-08-14
# 196486   I served w/Joseph &#34;Eddie&#34; Hair in the ...  2015-08-13
# 232130              Great resource with many Bible verses!  2015-08-10
# 241732   This book should have been part of the origina...  2015-08-09
# 269921                                   Interesting read!  2015-08-07
# 279156   .  If you like U.S. Naval aviation history<br ...  2015-08-06
# 283355   Great tips for differentiation, the book is ge...  2015-08-05
# 285765   This book is fantastic for anyone that has a c...  2015-08-05
# 308164   First off, this book has been on my TBR pile s...  2015-08-04
# 315197   The plan works but it is so confusing, I did l...  2015-08-03
# ...                                                    ...         ...
# 4449651  Excellent. A must read for anyone trying to be...  2014-07-29
# 4459300                                              Great  2014-07-28
# 4477211  I also was disappointed with this book.  Just ...  2014-07-26
# 4500861                               I love all her books  2014-07-24
# 4549884  Read her second book and had to buy this one. ...  2014-07-19
# 4552286  Much nicer than pictured. I was hesitant to or...  2014-07-19
# 4558857  Simply Great! The Doll paterns are much larger...  2014-07-18
# 4562249  Great book for those of us a little &#34;Too N...  2014-07-18
# 4567912        Good information I guess, but very limited.  2014-07-17
# 4633359                  great quality and speedy delivery  2014-07-11
# 4640815  I on the other hand am not pleased.  The bible...  2014-07-10
# 4644915                                Great learning tool  2014-07-10
# 4671851                            Moleskine is excellent.  2014-07-08
# 4701152                             Very satisfied........  2014-07-05
# 4721068                      What can I say it is perfect!  2014-07-03
# 4731354  ONE OF THE BEST BOOKS I EVER READ!  TRUE AND A...  2014-07-02
# 4744853  Insightful. Al & Jan share deep insights that ...  2014-06-30
# 4939718  I discovered Arno Elias in a Gallery in New Yo...  2014-06-03
# 5184881  I bought this book for my wife because shes so...  2014-04-30
# 5279518  I was shocked when I received this book. It co...  2014-04-17
# 5303008  The role of the German Schlieffen Plan in the ...  2014-04-14
# 5659630  Read both books of this series, and I feel thi...  2014-02-28
# 5893490  I read these books as a child and was very sad...  2014-02-02
# 5906171  Chris Howell writes and excellent book that ev...  2014-01-31
# 6053732  This author declares the book is based on true...  2014-01-14
# 6250798  I'm so thankful someone is out there who sells...  2013-12-26
# 6525508  Not a realistic diet give no advise for eating...  2013-11-20
# 6704023  I just received a copy of this Book. I didn't ...  2013-10-25
# 7724706  This cookbook is one of the favorites in my co...  2013-06-13
# 8647347  Here's the thing: Lillian Daniel is funny. *Ex...  2013-02-18
#
# [326 rows x 22 columns]

# %%
# Compute the proportion of long row
null_mask = df_reviews["undefined_1"].notnull()
print(null_mask.sum() )
print((~null_mask).sum())
# Out:
# 326
# 10236850

# %% [markdown]
# What is contained in the undefined columns is a bit weird, it's like we have more reviews, but they are not really related to the standard review column. For example, in the second line of the output, the review is "Was a great read..." and then we have "NOT PLEASED WITH THE VENDORS AT ALL" etc.
#
# These lines are not clear concerning the reviews. We also try to find these reviews on the amazon website. We found some of them, but we were only able to find the main reviews, and not the reviews contained in the additional columns. Besides, these rows are not coherent concerning the columns (some values represents something else than expected by the column name). Since we only have 326 of such rows over 10 millions, we decide to drop these rows. We can also drop the additional column since we won't need them anymore.
#
# Finally, we drop some other columns that we don't need

# %%
df_reviews = df_reviews[~null_mask]
df_reviews = df_reviews.iloc[:, :15]
df_reviews = df_reviews.drop(['product_parent', 
                              'product_category', 
                              'vine', 
                              'verified_purchase'], axis=1)

# %%
df_reviews["product_id"] = df_reviews["product_id"].astype('str')

# %% [markdown]
# Now we want to merge the reviews dataset with the covers dataset, in other word, for each reviews, we want to have the cover image of the book.

# %%
df_merge_1 = df_reviews.merge(df_covers, 
                              left_on='product_id', 
                              right_on='product_id', 
                              how='inner')

# %%
print(len(df_merge_1))
# Out:
# 1409974

# %% [markdown]
# From the 10M reviews, we have 1.4M that corresponds to a book from the 137'000 books of the covers dataset. The loss is consequent, but we still have a important dataset to work on. Moreover, we still have the two others reviews dataset to include in this dataframe.
#
# Note that we prefered not to load all three reviews dataset because of memory concerns. Our pipeline is : load covers, load review_1, merge, save merge as csv, load review_2, merge, save merge as csv, load review_3, merge, save merge as csv.

# %%
df_reviews = pd.read_csv("Data/amazon_reviews_us_Books_v1_01.tsv.gz", 
                         names=cols, 
                         sep='\t', 
                         skiprows=1)
# Out:
# /anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (7,17,18,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
null_mask = df_reviews["undefined_1"].notnull()
print(null_mask.sum() )
print((~null_mask).sum())
# Out:
# 1
# 6106190

# %%
df_reviews = df_reviews[~null_mask]
df_reviews = df_reviews.iloc[:, :15]
df_reviews = df_reviews.drop(['product_parent', 
                              'product_category', 
                              'vine', 
                              'verified_purchase'], axis=1)

# %%
df_reviews["product_id"] = df_reviews["product_id"].astype('str')

# %%
df_merge_2 = df_reviews.merge(df_covers, 
                              left_on='product_id', 
                              right_on='product_id', 
                              how='inner')

# %%
print(len(df_merge_2))
# Out:
# 359693

# %% [markdown]
# Finally the third reviews dataset

# %%
df_reviews = pd.read_csv("Data/amazon_reviews_us_Books_v1_02.tsv.gz", 
                         names=cols, 
                         sep='\t', 
                         skiprows=1)
# Out:
# /anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (17,18,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
null_mask = df_reviews["undefined_1"].notnull()
print(null_mask.sum() )
print((~null_mask).sum())
# Out:
# 1
# 3105370

# %%
df_reviews = df_reviews[~null_mask]
df_reviews = df_reviews.iloc[:, :15]
df_reviews = df_reviews.drop(['product_parent', 
                              'product_category', 
                              'vine', 
                              'verified_purchase'], axis=1)

# %%
df_reviews["product_id"] = df_reviews["product_id"].astype('str')

# %%
df_merge_3 = df_reviews.merge(df_covers, 
                            left_on='product_id', 
                            right_on='product_id', 
                            how='inner')

# %%
print(len(df_merge_3))
# Out:
# 72122

# %%
# append the dataframes
df_merge = df_merge_1.append(df_merge_2).append(df_merge_3)

# %%
df_merge.to_csv("Data/merge.csv", sep='\t', index=False)
